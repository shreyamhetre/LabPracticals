# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
  return (x+3)**2
def df(x):
  return 2*x + 6

# %%
def gradient_descent (initial_x , learning_rate , num_iterations):
  x = initial_x
  x_history = [x]
  for i in range (num_iterations):
    gradient = df(x)
    x = x-learning_rate * gradient
    x_history.append(x)
  return x , x_history

# %%
initial_x =2
learning_rate = 0.1
num_iterations = 50

x,x_history = gradient_descent(initial_x , learning_rate , num_iterations)
print("Local minimum: {:.2f}".format(x))
for i in range(len(x_history)):
  print(f"Iteration number{i}:{x_history[i]}")
# Out:
# Local minimum: -3.00
# Iteration number0:2
# Iteration number1:1.0
# Iteration number2:0.19999999999999996
# Iteration number3:-0.44000000000000017
# Iteration number4:-0.9520000000000001
# Iteration number5:-1.3616000000000001
# Iteration number6:-1.6892800000000001
# Iteration number7:-1.951424
# Iteration number8:-2.1611392
# Iteration number9:-2.32891136
# Iteration number10:-2.463129088
# Iteration number11:-2.5705032704
# Iteration number12:-2.6564026163200003
# Iteration number13:-2.725122093056
# Iteration number14:-2.7800976744448
# Iteration number15:-2.82407813955584
# Iteration number16:-2.8592625116446717
# Iteration number17:-2.8874100093157375
# Iteration number18:-2.90992800745259
# Iteration number19:-2.927942405962072
# Iteration number20:-2.9423539247696575
# Iteration number21:-2.953883139815726
# Iteration number22:-2.9631065118525806
# Iteration number23:-2.9704852094820646
# Iteration number24:-2.9763881675856516
# Iteration number25:-2.981110534068521
# Iteration number26:-2.984888427254817
# Iteration number27:-2.9879107418038537
# Iteration number28:-2.990328593443083
# Iteration number29:-2.9922628747544664
# Iteration number30:-2.993810299803573
# Iteration number31:-2.995048239842858
# Iteration number32:-2.9960385918742864
# Iteration number33:-2.9968308734994293
# Iteration number34:-2.9974646987995435
# Iteration number35:-2.997971759039635
# Iteration number36:-2.998377407231708
# Iteration number37:-2.998701925785366
# Iteration number38:-2.998961540628293
# Iteration number39:-2.9991692325026342
# Iteration number40:-2.9993353860021075
# Iteration number41:-2.999468308801686
# Iteration number42:-2.9995746470413485
# Iteration number43:-2.9996597176330786
# Iteration number44:-2.999727774106463
# Iteration number45:-2.99978221928517
# Iteration number46:-2.9998257754281363
# Iteration number47:-2.999860620342509
# Iteration number48:-2.999888496274007
# Iteration number49:-2.9999107970192056
# Iteration number50:-2.9999286376153647

# %%
x_vals = np.linspace(-11, 5, 50)

plt.plot(x_vals, f(x_vals))
plt.plot(x_history, f(np.array(x_history)), 'rx')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()
